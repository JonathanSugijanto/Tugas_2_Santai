# %% [markdown]
# # Kuis 1 FI3103 Metode Komputasi
# ## Nomor 3
# import csv dan plot

# %%
# import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# membaca csv
csv_filename = "task_3_out.csv"
df = pd.read_csv(csv_filename)
print(df)
# Out:
#         x  f(x)=sin(x)
# 0   0.133        0.132
# 1   0.782        0.705
# 2   0.369        0.361
# 3   0.397        0.387
# 4   0.574        0.543
# ..    ...          ...
# 95  0.002        0.002
# 96  0.396        0.386
# 97  0.537        0.511
# 98  0.729        0.666
# 99  0.314        0.309
#
# [100 rows x 2 columns]

# %%
# plot data dengan tipe scatter plot
df.plot(kind="scatter", x="x", y="f(x)=sin(x)")
# Out:
# <Axes: xlabel='x', ylabel='f(x)=sin(x)'>
